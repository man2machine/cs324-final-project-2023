# %%
import os
os.environ['HF_HOME'] = "C:/HF_CACHE/"

# %%
from cs324_project.evaluation import parse_task_results, plot_task_results, GlueDatasetTask

# %%
task = GlueDatasetTask.MRPC
results = parse_task_results(task)
plot_task_results(task, results, save=True)
# Out:
# Processing C:\Users\Shahir\Documents\Code Repositories\cs324-final-project-2023\models_save\mlm\mrpc\random
# Processing C:\Users\Shahir\Documents\Code Repositories\cs324-final-project-2023\models_save\mlm\mrpc\whole_word
# Processing C:\Users\Shahir\Documents\Code Repositories\cs324-final-project-2023\models_save\mlm\mrpc\typhoon
# Processing C:\Users\Shahir\Documents\Code Repositories\cs324-final-project-2023\models_save\sc\mrpc\random
# Processing C:\Users\Shahir\Documents\Code Repositories\cs324-final-project-2023\models_save\sc\mrpc\whole_word
# Processing C:\Users\Shahir\Documents\Code Repositories\cs324-final-project-2023\models_save\sc\mrpc\typhoon
# Masked Language Modeling MRPC Best Metrics for each Method
#                    Random  Whole Word   Typhoon
# Validation Loss  2.974313    3.226154  3.275054
# Sequence Classification MRPC Best Metrics for each Method
#                        Random  Whole Word   Typhoon
# Validation Loss      0.515548    0.490200  0.476349
# ...

# %%
task = GlueDatasetTask.COLA
results = parse_task_results(task)
plot_task_results(task, results, save=True)
# Out:
# Processing C:\Users\Shahir\Documents\Code Repositories\cs324-final-project-2023\models_save\mlm\cola\random
# Processing C:\Users\Shahir\Documents\Code Repositories\cs324-final-project-2023\models_save\mlm\cola\whole_word
# Processing C:\Users\Shahir\Documents\Code Repositories\cs324-final-project-2023\models_save\mlm\cola\typhoon
# Processing C:\Users\Shahir\Documents\Code Repositories\cs324-final-project-2023\models_save\sc\cola\random
# Processing C:\Users\Shahir\Documents\Code Repositories\cs324-final-project-2023\models_save\sc\cola\whole_word
# Processing C:\Users\Shahir\Documents\Code Repositories\cs324-final-project-2023\models_save\sc\cola\typhoon
# Masked Language Modeling COLA Best Metrics for each Method
#                    Random  Whole Word   Typhoon
# Validation Loss  3.005302    3.790712  3.703134
# Sequence Classification COLA Best Metrics for each Method
#                                    Random  Whole Word   Typhoon
# ...
